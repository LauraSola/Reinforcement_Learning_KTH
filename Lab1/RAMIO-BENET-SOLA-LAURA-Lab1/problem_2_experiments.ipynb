# %% [markdown]
# # Problem 2: SARSA(lambda) with function approximation
#
# Done by:
# - Benet Ramió i Comas (20031026T177)
# - Laura Sola Garcia (20031119T225)
#
# This file contains the contains the code to run the experiments and the analysis of the results for solving the Mountain Car environment implementing SARSA(lambda) with function aproximation
# The script 'problem2.py' of all the classes, methods and functions needed.

# %%
from problem_2 import *

# %% [markdown]
# ### FOURIER BASIS COEFFICIENTS

# %%
predefined_coeff_matrix_1 = np.array([
                [1, 0],
                [0, 1]
                ])


predefined_coeff_matrix_2 = np.array([
                [0, 1],
                [1, 0],
                [1, 1],
                ])

predefined_coeff_matrix_3 = np.array([
                [0, 0],
                [0, 1],
                [1, 0],
                [1, 1],
                ])

predefined_coeff_matrix_4 = np.array([
                [0, 1],
                [0, 2],
                [1, 0],
                [1, 1],
                [1, 2],
                [2, 0],
                [2, 1],
                [2, 2]
                ])

predefined_coeff_matrix_5 = np.array([
                [0, 0],
                [0, 1],
                [0, 2],
                [1, 0],
                [1, 1],
                [1, 2],
                [2, 0],
                [2, 1],
                [2, 2],
                ]) ##this is the same we get if we use default basis (max_non_zero = 2)

# %%
# Define hyperparameters as a dictionary
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ": 0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 1,  # LR reduction factor (fixed)
    "initialization": "zeros",  # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "predefined", 
    "defined_coeffs": [predefined_coeff_matrix_1, predefined_coeff_matrix_2, predefined_coeff_matrix_3, predefined_coeff_matrix_4, predefined_coeff_matrix_5],
}

# Run the hyperparameter search
all_rewards, all_labels,  test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=300, test_episodes=50)

labels = [r'$\eta_1$', '$\eta_2$', '$\eta_3$', '$\eta_4$', '$\eta_5$']
# Plot results
plot_all_smoothed_rewards(all_rewards, window_size=20, labels=labels, cf=False)
# Out:
# Starting training for combination 1/5: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[1, 0],
#        [0, 1]])}
# 100%|██████████| 300/300 [00:06<00:00, 47.67it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 100.01it/s]
# Policy achieves an average total reward of -200.0 +/- 0.0 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 1 completed!
# Starting training for combination 2/5: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[0, 1],
#        [1, 0],
#        [1, 1]])}
# 100%|██████████| 300/300 [00:05<00:00, 53.89it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 145.22it/s]
# Policy achieves an average total reward of -135.4 +/- 9.5 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 2 completed!
# Starting training for combination 3/5: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])}
# 100%|██████████| 300/300 [00:05<00:00, 59.60it/s]
# Training for combination 3 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 147.94it/s]
# Policy achieves an average total reward of -132.8 +/- 9.4 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 3 completed!
# Starting training for combination 4/5: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]])}
# 100%|██████████| 300/300 [00:04<00:00, 65.77it/s]
# Training for combination 4 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 123.14it/s]
# Policy achieves an average total reward of -152.2 +/- 6.9 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 4 completed!
# Starting training for combination 5/5: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]])}
# 100%|██████████| 300/300 [00:04<00:00, 63.45it/s]
# Training for combination 5 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 148.19it/s]
# Policy achieves an average total reward of -135.8 +/- 1.4 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 5 completed!

# %%
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ": 0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 1,  # LR reduction factor (fixed)
    "initialization": "zeros",  # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "predefined", 
    "defined_coeffs": [ predefined_coeff_matrix_2, predefined_coeff_matrix_3],
}

# Run the hyperparameter search
all_rewards, all_labels,  test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=500, test_episodes=50)

labels = [r'$\eta_2$ - no zeros', '$\eta_3$ - with zeros']
# Plot results
plot_all_smoothed_rewards(all_rewards, window_size=20, labels=labels, cf=False)
# Out:
# Starting training for combination 1/2: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[0, 1],
#        [1, 0],
#        [1, 1]])}
# 100%|██████████| 500/500 [00:08<00:00, 58.84it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 146.81it/s]
# Policy achieves an average total reward of -137.3 +/- 0.8 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 1 completed!
# Starting training for combination 2/2: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])}
# 100%|██████████| 500/500 [00:07<00:00, 65.86it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 143.65it/s]
# Policy achieves an average total reward of -138.8 +/- 0.8 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 2 completed!

# %%
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ": 0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 1,  # LR reduction factor (fixed)
    "initialization": "zeros",  # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "predefined", 
    "defined_coeffs": [predefined_coeff_matrix_4, predefined_coeff_matrix_5],
}

# Run the hyperparameter search
all_rewards, all_labels,  test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=300, test_episodes=50)

labels = [r'$\eta_4$ - no zeros', '$\eta_5$ - with zeros']
# Plot results
plot_all_smoothed_rewards(all_rewards, window_size=20, labels=labels, cf=False)
# Out:
# Starting training for combination 1/2: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]])}
# 100%|██████████| 300/300 [00:04<00:00, 68.06it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 148.86it/s]
# Policy achieves an average total reward of -138.9 +/- 4.2 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 1 completed!
# Starting training for combination 2/2: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'predefined', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]])}
# 100%|██████████| 300/300 [00:04<00:00, 69.33it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 148.78it/s]
# Policy achieves an average total reward of -136.0 +/- 1.8 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 2 completed!

# %% [markdown]
# ### LEARNING RATE

# %%
# Define hyperparameters as a dictionary
hyperparameters = {
    "alpha": [0.0001, 0.001, 0.01, 0.1],  # Learning rate
    "λ": 0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.3,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 1,  # LR reduction factor (fixed)
    "initialization": "zeros",  # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}

# Run the hyperparameter search
all_rewards, all_labels,  test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=200, test_episodes=50)

# Plot results
plot_all_smoothed_rewards(all_rewards, window_size=50, labels=all_labels, cf=True)
# Out:
# Starting training for combination 1/4: {'λ': 0.6, 'gamma': 1, 'epsilon': 0.3, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'alpha': 0.0001}
# 100%|██████████| 200/200 [00:03<00:00, 50.84it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 157.20it/s]
# Policy achieves an average total reward of -126.4 +/- 4.1 with confidence 95%.
# Your policy passed the test!
# Testing for combination 1 completed!
# Starting training for combination 2/4: {'λ': 0.6, 'gamma': 1, 'epsilon': 0.3, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'alpha': 0.001}
# 100%|██████████| 200/200 [00:02<00:00, 70.09it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 159.81it/s]
# Policy achieves an average total reward of -130.1 +/- 6.1 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 2 completed!
# Starting training for combination 3/4: {'λ': 0.6, 'gamma': 1, 'epsilon': 0.3, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'alpha': 0.01}
# 100%|██████████| 200/200 [00:03<00:00, 52.83it/s]
# Training for combination 3 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 104.53it/s]
# Policy achieves an average total reward of -200.0 +/- 0.0 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 3 completed!
# Starting training for combination 4/4: {'λ': 0.6, 'gamma': 1, 'epsilon': 0.3, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'alpha': 0.1}
# 100%|██████████| 200/200 [00:03<00:00, 50.94it/s]
# Training for combination 4 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 107.39it/s]
# Policy achieves an average total reward of -200.0 +/- 0.0 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 4 completed!

# %%
# Define hyperparameters as a dictionary
hyperparameters = {
    "alpha": [0.0001, 0.001, 0.01, 0.1],  # Learning rate
    "λ": 0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 1,  # LR reduction factor (fixed)
    "initialization": "zeros",  # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}

# Run the hyperparameter search
all_rewards, all_labels, test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=300, test_episodes=50)

# Plot results
#plot_all_smoothed_rewards(all_rewards, window_size=50, labels=all_labels, cf=False)
plot_test_results_lr(test_avg_rewards, test_confidences, [0.0001, 0.001, 0.01, 0.1])
# Out:
# Starting training for combination 1/4: {'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'alpha': 0.0001}
# 100%|██████████| 300/300 [00:05<00:00, 57.46it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 138.74it/s]
# Policy achieves an average total reward of -148.0 +/- 8.6 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 1 completed!
# Starting training for combination 2/4: {'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'alpha': 0.001}
# 100%|██████████| 300/300 [00:04<00:00, 71.43it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 154.09it/s]
# Policy achieves an average total reward of -134.4 +/- 1.4 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 2 completed!
# Starting training for combination 3/4: {'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'alpha': 0.01}
# 100%|██████████| 300/300 [00:05<00:00, 51.79it/s]
# Training for combination 3 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 103.90it/s]
# Policy achieves an average total reward of -200.0 +/- 0.0 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 3 completed!
# Starting training for combination 4/4: {'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 1, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'alpha': 0.1}
# 100%|██████████| 300/300 [00:06<00:00, 49.29it/s]
# Training for combination 4 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 107.31it/s]
# Policy achieves an average total reward of -200.0 +/- 0.0 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 4 completed!

# %%
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ": 0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": [1,0.7, 0.5,0.3],  # LR reduction factor (fixed)
    "initialization": "zeros",  # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}

# Run the hyperparameter search
all_rewards, all_labels,  test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=200, test_episodes=50)

# Plot results
plot_all_smoothed_rewards(all_rewards, window_size=50, labels=all_labels, cf=False)
# Out:
# Starting training for combination 1/4: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'reduction factor': 1}
# 100%|██████████| 200/200 [00:02<00:00, 72.68it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 148.51it/s]
# Policy achieves an average total reward of -146.2 +/- 8.0 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 1 completed!
# Starting training for combination 2/4: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'reduction factor': 0.7}
# 100%|██████████| 200/200 [00:02<00:00, 74.32it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 175.16it/s]
# Policy achieves an average total reward of -119.8 +/- 6.4 with confidence 95%.
# Your policy passed the test!
# Testing for combination 2 completed!
# Starting training for combination 3/4: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'reduction factor': 0.5}
# 100%|██████████| 200/200 [00:02<00:00, 75.31it/s]
# Training for combination 3 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 180.31it/s]
# Policy achieves an average total reward of -118.6 +/- 4.9 with confidence 95%.
# Your policy passed the test!
# Testing for combination 3 completed!
# Starting training for combination 4/4: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'reduction factor': 0.3}
# 100%|██████████| 200/200 [00:02<00:00, 74.35it/s]
# Training for combination 4 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 173.46it/s]
# Policy achieves an average total reward of -118.2 +/- 3.8 with confidence 95%.
# Your policy passed the test!
# Testing for combination 4 completed!

# %% [markdown]
# ### ELEGIBILITY TRACE

# %%
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ": [0.8, 0.6, 0.4, 0],      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 0.7,  # LR reduction factor (fixed)
    "initialization": "zeros",  # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}

# Run the hyperparameter search
all_rewards, all_labels, test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=300, test_episodes=50)

# Plot results
plot_all_smoothed_rewards(all_rewards, window_size=50, labels=all_labels, cf=False)
#plot_test_results(test_avg_rewards, test_confidences, [1, 0.8, 0.6, 0.4, 0])
# Out:
# Starting training for combination 1/4: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.8}
# 100%|██████████| 300/300 [00:04<00:00, 67.07it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 164.20it/s]
# Policy achieves an average total reward of -133.3 +/- 1.8 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 1 completed!
# Starting training for combination 2/4: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.6}
# 100%|██████████| 300/300 [00:04<00:00, 72.43it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 166.01it/s]
# Policy achieves an average total reward of -124.8 +/- 4.6 with confidence 95%.
# Your policy passed the test!
# Testing for combination 2 completed!
# Starting training for combination 3/4: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.4}
# 100%|██████████| 300/300 [00:04<00:00, 74.79it/s]
# Training for combination 3 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 167.45it/s]
# Policy achieves an average total reward of -124.6 +/- 7.8 with confidence 95%.
# Your policy passed the test!
# Testing for combination 3 completed!
# Starting training for combination 4/4: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0}
# 100%|██████████| 300/300 [00:04<00:00, 72.45it/s]
# Training for combination 4 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 136.81it/s]
# Policy achieves an average total reward of -134.9 +/- 8.8 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 4 completed!

# %%
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ": [0.9, 0.8, 0.7, 0.6, 0.5,0.4, 0.3, 0.2, 0.1,0],      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 0.7,  # LR reduction factor (fixed)
    "initialization": "zeros",  # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}

# Run the hyperparameter search
all_rewards, all_labels, test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=300, test_episodes=50)

# Plot results
#plot_all_smoothed_rewards(all_rewards, window_size=50, labels=all_labels, cf=False)
plot_test_results_lamb(test_avg_rewards, test_confidences, [0.9, 0.8, 0.7, 0.6, 0.5,0.4, 0.3, 0.2, 0.1,0])
# Out:
# Starting training for combination 1/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.9}
# 100%|██████████| 300/300 [00:05<00:00, 56.34it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 135.49it/s]
# Policy achieves an average total reward of -157.0 +/- 5.4 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 1 completed!
# Starting training for combination 2/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.8}
# 100%|██████████| 300/300 [00:04<00:00, 70.76it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 142.86it/s]
# Policy achieves an average total reward of -134.0 +/- 1.2 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 2 completed!
# Starting training for combination 3/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.7}
# 100%|██████████| 300/300 [00:04<00:00, 69.88it/s]
# Training for combination 3 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 153.02it/s]
# Policy achieves an average total reward of -127.3 +/- 4.3 with confidence 95%.
# Your policy passed the test!
# Testing for combination 3 completed!
# Starting training for combination 4/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.6}
# 100%|██████████| 300/300 [00:04<00:00, 73.77it/s]
# Training for combination 4 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 168.28it/s]
# Policy achieves an average total reward of -121.3 +/- 5.6 with confidence 95%.
# Your policy passed the test!
# Testing for combination 4 completed!
# Starting training for combination 5/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.5}
# 100%|██████████| 300/300 [00:04<00:00, 72.33it/s]
# Training for combination 5 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 165.24it/s]
# Policy achieves an average total reward of -126.4 +/- 3.9 with confidence 95%.
# Your policy passed the test!
# Testing for combination 5 completed!
# Starting training for combination 6/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.4}
# 100%|██████████| 300/300 [00:03<00:00, 75.18it/s]
# Training for combination 6 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 151.96it/s]
# Policy achieves an average total reward of -125.3 +/- 8.5 with confidence 95%.
# Your policy passed the test!
# Testing for combination 6 completed!
# Starting training for combination 7/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.3}
# 100%|██████████| 300/300 [00:04<00:00, 71.77it/s]
# Training for combination 7 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 166.66it/s]
# Policy achieves an average total reward of -127.1 +/- 7.8 with confidence 95%.
# Your policy passed the test!
# Testing for combination 7 completed!
# Starting training for combination 8/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.2}
# 100%|██████████| 300/300 [00:04<00:00, 72.23it/s]
# Training for combination 8 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 164.83it/s]
# Policy achieves an average total reward of -123.0 +/- 7.0 with confidence 95%.
# Your policy passed the test!
# Testing for combination 8 completed!
# Starting training for combination 9/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.1}
# 100%|██████████| 300/300 [00:04<00:00, 72.90it/s]
# Training for combination 9 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 143.98it/s]
# Policy achieves an average total reward of -141.2 +/- 10.3 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 9 completed!
# Starting training for combination 10/10: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0}
# 100%|██████████| 300/300 [00:04<00:00, 70.62it/s]
# Training for combination 10 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 165.88it/s]
# Policy achieves an average total reward of -126.3 +/- 7.8 with confidence 95%.
# Your policy passed the test!
# Testing for combination 10 completed!

# %% [markdown]
# ### INITIALIZATION

# %%
# Define hyperparameters as a dictionary
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ":  0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 0.7,  # LR reduction factor (fixed)
    "initialization": ["zeros",  "random uniform", "random gaussian"], # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}


rewards = []
# Run the hyperparameter search three times
for i in range(40):
    all_rewards, all_labels, test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=300, test_episodes=50)
    rewards.append(all_rewards)

rewards_zeros = []
rewards_random_uniform = []
rewards_random_gaussian = []

for i in range(len(rewards)):
    #plot_all_smoothed_rewards(rewards[i], window_size=50, labels=all_labels, cf=False)
    rewards_zeros.append(rewards[i][0])
    rewards_random_uniform.append(rewards[i][1])
    rewards_random_gaussian.append(rewards[i][2])

# plot all results with error bars
mean_rewards_zeros = np.mean(rewards_zeros, axis=0)
std_rewards_zeros = np.std(rewards_zeros, axis=0)
mean_rewards_random_uniform = np.mean(rewards_random_uniform, axis=0)
std_rewards_random_uniform = np.std(rewards_random_uniform, axis=0)
mean_rewards_random_gaussian = np.mean(rewards_random_gaussian, axis=0)


plt.figure(figsize=(12, 6))
plt.title("Effect of Weight Initialization on Performance")
plt.plot(np.mean(rewards_zeros, axis=0), label="Zeros")
plt.plot(np.mean(rewards_random_uniform, axis=0), label="Random Uniform")
plt.plot(np.mean(rewards_random_gaussian, axis=0), label="Random Gaussian")
plt.xlabel("Episodes")
plt.ylabel("Average Reward")
plt.legend()
plt.show()

# %% [markdown]
# ### EXPLORATION STRATEGY

# %%
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ":  0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": [0.1, 0.3, 0.5, 0.7],          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 0.7,  # LR reduction factor (fixed)
    "initialization": "zeros", # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}

# Run the hyperparameter search
all_rewards, all_labels, test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=300, test_episodes=50)

# Plot results
plot_all_smoothed_rewards(all_rewards, window_size=50, labels=all_labels, cf=False)
#plot_test_results(test_avg_rewards, test_confidences, [1, 0.8, 0.6, 0.4, 0])
# Out:
# Starting training for combination 1/4: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'epsilon': 0.1}
# 100%|██████████| 300/300 [00:03<00:00, 75.46it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 146.96it/s]
# Policy achieves an average total reward of -123.5 +/- 4.6 with confidence 95%.
# Your policy passed the test!
# Testing for combination 1 completed!
# Starting training for combination 2/4: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'epsilon': 0.3}
# 100%|██████████| 300/300 [00:04<00:00, 67.77it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 136.55it/s]
# Policy achieves an average total reward of -133.9 +/- 6.5 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 2 completed!
# Starting training for combination 3/4: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'epsilon': 0.5}
# 100%|██████████| 300/300 [00:04<00:00, 67.04it/s]
# Training for combination 3 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 142.37it/s]
# Policy achieves an average total reward of -130.8 +/- 3.1 with confidence 95%.
# Your policy passed the test!
# Testing for combination 3 completed!
# Starting training for combination 4/4: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'epsilon': 0.7}
# 100%|██████████| 300/300 [00:04<00:00, 66.44it/s]
# Training for combination 4 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 154.84it/s]
# Policy achieves an average total reward of -136.3 +/- 2.2 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 4 completed!

# %%
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ":  0.6,      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon": 0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 0.7,  # LR reduction factor (fixed)
    "initialization": "zeros", # Weight initialization
    "expl_strategy": ["e-greedy", "boltzmann", "worst"],
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}

# Run the hyperparameter search
all_rewards, all_labels, test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=300, test_episodes=50)

# Plot results
plot_all_smoothed_rewards(all_rewards, window_size=50, labels=all_labels, cf=False)
#plot_test_results(test_avg_rewards, test_confidences, [1, 0.8, 0.6, 0.4, 0])
# Out:
# Starting training for combination 1/3: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'expl_strategy': 'e-greedy'}
# 100%|██████████| 300/300 [00:03<00:00, 75.86it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 166.10it/s]
# Policy achieves an average total reward of -131.3 +/- 5.6 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 1 completed!
# Starting training for combination 2/3: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'expl_strategy': 'boltzmann'}
# 100%|██████████| 300/300 [00:06<00:00, 48.38it/s]
# Training for combination 2 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 99.60it/s]
# Policy achieves an average total reward of -128.7 +/- 7.7 with confidence 95%.
# Your policy did not pass the test! The average reward of your policy needs to be greater than -135 with 95% confidence
# Testing for combination 2 completed!
# Starting training for combination 3/3: {'alpha': 0.001, 'λ': 0.6, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'expl_strategy': 'worst'}
# 100%|██████████| 300/300 [00:03<00:00, 76.16it/s]
# Training for combination 3 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 156.68it/s]
# Policy achieves an average total reward of -125.9 +/- 4.2 with confidence 95%.
# Your policy passed the test!
# Testing for combination 3 completed!

# %% [markdown]
# ### TRAINING PLOT EPISODIC REWARDS

# %%
hyperparameters = {
    "alpha": 0.001,  # Learning rate
    "λ":  [0.6],      # λ for eligibility traces
    "gamma": 1,              # Discount factor (fixed)
    "epsilon":0.1,          # Exploration probability (fixed)
    "fourier_order": 2,      # Fourier order (fixed)
    "max_non_zero_fourier": 2,  # Max non-zero Fourier coefficients (fixed)
    "reduction factor": 0.7,  # LR reduction factor (fixed)
    "initialization": "zeros", # Weight initialization
    "expl_strategy": "e-greedy",
    "type_coeffs": "nothing", 
    "defined_coeffs":  predefined_coeff_matrix_5,
}

# Run the hyperparameter search
all_rewards, all_labels, test_avg_rewards, test_confidences = run_hyperparameter_search(hyperparameters, num_episodes=200, test_episodes=50)

# Parameters for smoothing
rewards = all_rewards[0]
window_size = 20  # Adjust the window size for more or less smoothing
smoothed_rewards, _ = compute_smoothed_rewards(rewards, window_size)

# Plotting
plt.figure(figsize=(10, 6))
x_vals = np.arange(len(rewards))
#x_vals2 = np.arange(len(smoothed_rewards))
plt.plot(x_vals, rewards, label="Raw Rewards", alpha=0.6)
plt.plot(x_vals, smoothed_rewards[1:], label="Smoothed Rewards", color="orange", linewidth=2)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("Rewards and Smoothed Rewards")
plt.legend()
plt.grid()
plt.show()
# Out:
# Starting training for combination 1/1: {'alpha': 0.001, 'gamma': 1, 'epsilon': 0.1, 'fourier_order': 2, 'max_non_zero_fourier': 2, 'reduction factor': 0.7, 'initialization': 'zeros', 'expl_strategy': 'e-greedy', 'type_coeffs': 'nothing', 'defined_coeffs': array([[0, 0],
#        [0, 1],
#        [0, 2],
#        [1, 0],
#        [1, 1],
#        [1, 2],
#        [2, 0],
#        [2, 1],
#        [2, 2]]), 'λ': 0.6}
# 100%|██████████| 200/200 [00:03<00:00, 57.81it/s]
# Training for combination 1 completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 159.32it/s]
# Policy achieves an average total reward of -125.1 +/- 8.0 with confidence 95%.
# Your policy passed the test!
# Testing for combination 1 completed!

# %% [markdown]
# ### PLOT SOLUTION: V-FUNCTION AND POLICY

# %%
# Initialize environment
env = gym.make('MountainCar-v0')

# Set hyperparameters for SARSA(λ)
state_space = env.observation_space
action_space = env.action_space
alpha = 0.001  # Learning rate
lamb = 0.6  # λ value for eligibility traces
gamma = 1  # Discount factor
epsilon = 0.1  # Exploration probability
fourier_order = 2  # Fourier order
max_non_zero_fourier = 2  # Max non-zero Fourier coefficients
reduction_factor = 0.7
initialization = "zeros"
expl_strategy = "e-greedy"
type_coeffs = "nothing"
defined_coeffs = predefined_coeff_matrix_5
num_episodes = 200
early_stopping = False


# Initialize SARSA(λ) agent
agent = SarsaLambda(
    state_space=env.observation_space,
    action_space=env.action_space,
    alpha=alpha,
    lamb=lamb,
    gamma=gamma,
    epsilon=epsilon,
    fourier_order=fourier_order,
    max_non_zero_fourier=max_non_zero_fourier,
    reduction_factor=reduction_factor,
    initialization=initialization,
    expl_strategy=expl_strategy,
    type_coeffs=type_coeffs,
    defined_coeffs=defined_coeffs
)

# Initialize trainer
trainer = Trainer(
    environment=env,
    agent=agent,
    epsilon=epsilon,
    number_episodes=num_episodes,
    episode_reward_trigger=-150,
    early_stopping=early_stopping,
)

# Train the agent
print("Starting training...")
trainer.train()
print("Training completed!")
trainer.test(N=50, verbose=True)
print("Testing completed!")

# Plot training results
plt.plot(trainer.episode_reward_list)
plt.title("Episode Rewards Over Time")
plt.xlabel("Episodes")
plt.ylabel("Total Reward")
plt.show()


# Plot the value function
position_grid, velocity_grid, v_values = agent.get_v_function()
plot_v_function(position_grid, velocity_grid, v_values)

# Plot the optimal policy 
position_grid, velocity_grid, optimal_policy = agent.get_policy()
plot_policy(position_grid, velocity_grid, optimal_policy)

env.close()
# Out:
# Starting training...
# 100%|██████████| 200/200 [00:03<00:00, 64.76it/s]
# Training completed!
# Checking solution...
# Episode: 100%|██████████| 50/50 [00:00<00:00, 167.92it/s]
# Policy achieves an average total reward of -119.2 +/- 4.2 with confidence 95%.
# Your policy passed the test!
# Testing completed!
